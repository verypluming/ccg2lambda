# %%
from time import time
import pandas as pd
import numpy as np
from gensim.models import KeyedVectors
import re
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
#import seaborn as sns

import itertools
import datetime

from keras.preprocessing.sequence import pad_sequences
from keras.models import Model
from keras.layers import Input, Embedding, LSTM, Merge, Bidirectional, Dense, Concatenate
import keras.backend as K
from keras.optimizers import Adadelta
from keras.callbacks import ModelCheckpoint

from keras.models import load_model
from gensim import corpora
import glob

# %%
with open('features_phrase_classifier_ae01b34_sick_maxmin.pickle', 'rb') as in_f:
    load_target = np.load(in_f)
    load_source = np.load(in_f)
    load_source_phrase = np.load(in_f)
    load_sick_id = np.load(in_f)

# %%
np.set_printoptions(threshold=np.inf)
load_source_phrase2[np.where(load_target2==0)]
# Out:
# array(['climb_climb_make', 'climb_climb_of', 'climb_climb_hold',
#        'mountain_mountain_rope', 'climb_climb_rock',
#        'mountain_mountain_wall', 'dog_dog_for', 'dog_dog_racing',
#        'muzzle_muzzle_striped', 'muzzle_muzzle_track',
#        'muzzle_muzzle_uniform', 'race_dog_run', 'have_dog_wear',
#        'have_dog_down', 'dog_dog_breed', 'woman_woman_man', 'egg_egg_dog',
#        'woman_woman_man', 'egg_egg_two', 'jetskus_jetskus_seadoo',
#        'person_person_woman', 'woman_woman_man', 'man_two_make',
#        'beat_bowl_in', 'beat_bowl_use', 'two_man_of',
#        'watching_family_watch', 'wear_walk_beach', 'walk_wear_on',
#        'walk_wear_run', 'hat_hat_white', 'building_to_distance',
#        'to_walk_between', 'walk_to_look', 'walk_to_people',
#        'next_to_behind', 'to_walk_into', 'seasoning_seasoning_sausage',
#        'add_add_season', 'stand_stand_watch', 'stand_stand_breathlessly',
#        'stand_stand_laugh', 'girl_asian_two', 'down_lie_on',
#        'panda_down_log', 'panda_down_bear', 'lick_lick_with',
#        'lick_bottle_small', 'lick_lick_play', 'bike_bike_car',
#        'down_walk_along', 'walk_down_path', 'down_walk_through',
#        'walk_down_wilderness', 'jump_jump_up', 'large_dog_small',
#        'air_air_snow', 'ramp_woman_helmet', 'ramp_woman_bike',
#        'woman_ramp_girl', 'perform_perform_perch', 'play_crocodile_push',
#        'float_green_inflatable', 'boy_man_woman', 'sword_sword_plastic',
#        'whack_man_spank', 'stand_next_climb', 'man_man_mimes',
#        'act_act_perform', 'tap_tap_nervously', 'walk_walk_play',
#        'walk_walk_down', 'four_people_person',
#        'rollerbladers_rollerbladers_rollerblader', 'door_door_onion',
#        'open_open_cut', 'slide_slide_down', 'girl_young_child',
#        'young_girl_blond', 'slide_slide_go', 'hand_slide_arm',
#        'slide_slide_throw', 'slide_slide_up', 'man_man_cat',
#        'read_sit_read', 'other_small_together', 'smoke_smoke_smoking',
#        'smoke_smoke_wear', 'straw_cigarette_hat', 'water_drink_bottle',
#        'field_field_drink', 'drink_sit_from', 'player_soccer_man',
#        'field_field_grass', 'woman_woman_man', 'slice_slice_cut',
#        'man_man_woman', 'horse_horse_elephant', 'piano_piano_player',
#        'piano_piano_tough', 'piano_piano_man',
#        'rollerblader_rollerblader_rollerbladers', 'dive_off_ride',
#        'cliff_cliff_motorcycle', 'play_play_woman', 'play_play_run',
#        'play_play_from', 'park_park_blue', 'play_play_away',
#        'people_people_three', 'rope_bridge_wood', 'stream_rocky_river',
#        'stand_play_in', 'young_play_shoulder', 'stand_play_sweater',
#        'young_play_man', 'play_stand_blue', 'pinwheel_pinwheel_hair',
#        'pinwheel_pinwheel_grey', 'stand_play_hold', 'stand_play_sit',
#        'stand_play_on', 'stand_play_in', 'young_play_shoulder',
#        'stand_play_sweater', 'young_play_man', 'play_stand_blue',
#        'pinwheel_pinwheel_hair', 'pinwheel_pinwheel_grey',
#        'stand_play_hold', 'stand_play_sit', 'stand_play_on',
#        'girl_girl_woman', 'get_get_sweater', 'hand_hand_teenager',
#        'get_get_white', 'get_get_in', 'get_get_draw', 'slice_slice_peel',
#        'tomato_tomato_potato', 'stare_stare_at', 'stare_stare_across',
#        'dog_black_breed', 'dog_black_two', 'white_black_different',
#        'stare_stare_look', 'stare_stare_street', 'look_look_around',
#        'laugh_laugh_cry', 'laugh_laugh_cry', 'ride_ride_open',
#        'ride_ride_drink', 'girl_girl_nake', 'two_man_together',
#        'woman_two_people', 'man_homeless_woman', 'hold_up_travel',
#        'man_homeless_car', 'crowd_racing_people', 'two_car_out',
#        'two_car_come', 'two_car_of', 'racing_crowd_flame', 'sit_in_trot',
#        'in_sit_through', 'boy_car_young', 'boy_front_man',
#        'burn_burn_behind', 'front_boy_four', 'burn_burn_explode',
#        'stand_stand_still', 'run_wear_in', 'boy_little_child',
#        'run_strip_and', 'run_soccer_rest', 'person_person_woman',
#        'strongly_whisk_make', 'egg_egg_whisk', 'whisk_strongly_wire',
#        'strongly_whisk_of', 'strongly_whisk_use', 'egg_egg_two',
#        'whisk_strongly_beat', 'guitar_guitar_drum', 'gear_full_uniform',
#        'gear_full_motocross', 'man_helmet_person', 'jump_ball_miss',
#        'air_air_mid', 'drill_drill_close', 'dog_dog_great',
#        'run_run_climb', 'gym_gym_middle', 'black_stand_wear',
#        'sit_sit_front', 'sit_sit_restaurant', 'sit_sit_in',
#        'man_man_person', 'drum_drum_guitar', 'flute_flute_guitar',
#        'woman_woman_bicyclist', 'lion_lion_person', 'take_set_away',
#        'set_up_put', 'take_up_walk', 'up_take_from', 'near_barrel_from',
#        'near_red_far', 'black_dog_little', 'person_black_owner',
#        'sit_sit_take', 'play_play_at', 'play_play_point', 'play_play_car',
#        'sit_sit_against', 'adult_five_people', 'sit_sit_wall',
#        'two_people_angel', 'angel_angel_lie', 'angel_angel_on',
#        'angel_angel_child', 'white_bird_black', 'boy_boy_kid',
#        'instrument_instrument_guitar', 'camera_internet_webcam',
#        'talk_talk_in', 'man_girl_boy', 'talk_talk_teens', 'man_old_knife',
#        'jump_jump_sit', 'watch_watch_dye', 'watch_watch_black',
#        'watch_watch_from', 'watch_watch_serious', 'watch_watch_walk',
#        'watch_watch_away', 'man_a_purple', 'man_watch_shirt',
#        'watch_watch_in', 'nail_nail_nail', 'nail_nail_against',
#        'nail_nail_bang', 'child_two_boy', 'water_dirty_ocean',
#        'two_child_close', 'roll_roll_lay', 'open_open_wear',
#        'lie_woman_sing', 'woman_woman_seat', 'book_book_song',
#        'lie_woman_play', 'book_book_guitar', 'beat_beat_bowl',
#        'beat_beat_in', 'beat_beat_stir', 'ride_ride_trail',
#        'two_people_biker', 'two_people_dirt', 'ride_ride_on',
#        'camera_man_lens', 'man_man_hairy', 'ride_motorcycle_near',
#        'ride_motorcycle_stand', 'lie_woman_sing', 'book_book_guitar',
#        'book_book_song', 'lie_woman_play', 'woman_woman_seat',
#        'vicinity_look_in', 'vicinity_look_direction',
#        'look_vicinity_gather', 'costume_look_same',
#        'costume_vicinity_wear', 'piano_piano_guitar', 'to_sauce_from',
#        'lady_lady_woman', 'to_sauce_remove', 'motorcycle_motorcycle_bike',
#        'water_jump_near', 'in_in_front', 'jump_body_get',
#        'jump_body_airborne', 'front_jump_on', 'water_jump_track',
#        'water_jump_skyline', 'camp_grass_hike', 'in_camp_through',
#        'man_woman_stage', 'dance_dance_walk', 'man_woman_a',
#        'dance_dance_off', 'suffer_day_enjoy', 'sunny_suffer_on',
#        'suffer_day_enjoy', 'sunny_suffer_on', 'rider_rider_surfboard',
#        'wave_wave_trick', 'rider_rider_man', 'hold_woman_look',
#        'asian_woman_dress', 'woman_asian_elegant', 'asian_woman_clothing',
#        'asian_woman_in', 'hold_woman_up', 'woman_hold_crowd',
#        'hold_woman_inside', 'woman_asian_people', 'shirt_clown_tie',
#        'orange_clown_striped', 'woman_woman_girl', 'shirt_clown_wear',
#        'baby_baby_man', 'cabinet_wooden_table', 'outside_window_out',
#        'grate_grate_coat', 'carrot_carrot_pork', 'carrot_carrot_chop',
#        'bike_bike_green', 'person_air_man', 'bike_bike_dirt',
#        'bike_bike_ramp', 'bike_bike_car', 'dirt_bike_sandy',
#        'man_young_biker', 'bike_motocross_bike', 'push_motocross_get',
#        'stand_people_carnival', 'group_group_stand', 'woman_woman_man',
#        'meat_meat_dough', 'rollerbladers_rollerbladers_rollerblader',
#        'along_walk_beside', 'river_carefully_brown', 'boy_three_man',
#        'river_walk_shorts', 'along_carefully_in',
#        'racer_motorcycle_woman', 'racer_motorcycle_racing',
#        'man_man_woman', 'cut_cut_slice', 'leaf_leaf_dry',
#        'dog_black_animal', 'wear_with_jump', 'ball_with_soccer',
#        'leaf_leaf_field', 'with_blue_at', 'blue_wear_shiny',
#        'play_keyboard_dance', 'dance_keyboard_play', 'down_put_wear',
#        'dance_dance_speak', 'stand_fence_jump', 'inside_stand_over',
#        'fence_stand_cyclone', 'animal_belly_lemur', 'put_away_play',
#        'paper_piece_tear', 'man_man_person', 'surfer_surfer_yellow',
#        'surfer_surfer_surf', 'surfer_surfer_woman', 'surfer_surfer_shirt',
#        'snow_difficultly_landscape', 'walk_snow_tread',
#        'thick_difficultly_beautiful', 'thick_walk_through',
#        'snow_difficultly_snowy', 'person_person_climber', 'rock_rock_man',
#        'person_person_social', 'person_person_cliff', 'person_meat_trash',
#        'person_meat_woman', 'boy_young_girl', 'wear_have_gear',
#        'have_wear_in', 'wear_have_sit', 'wear_have_swimming',
#        'monkey_monkey_small', 'river_river_water', 'wade_wade_walk',
#        'girl_girl_man', 'teammate_football_hug', 'teammate_football_jump',
#        'land_white_fly', 'white_bird_water', 'land_bird_large',
#        'bird_white_crane', 'tree_small_scooter', 'elephant_baby_little',
#        'baby_elephant_girl', 'play_play_disassemble', 'place_place_dry',
#        'grey_grey_two', 'grey_grey_poodle', 'jump_jump_high',
#        'bore_kitten_blue', 'bore_kitten_play', 'kitten_bore_toy',
#        'bore_kitten_rope', 'kitten_bore_with', 'shallow_shallow_deep',
#        'cross_black_front', 'black_cross_man', 'lady_lady_woman',
#        'cross_white_cart', 'white_dress_two', 'slice_slice_peel',
#        'people_people_sun', 'tread_through_stand', 'snow_tread_thick',
#        'through_tread_in', 'people_people_four', 'on_grass_of',
#        'play_grass_run', 'play_grass_out', 'sit_next_stand',
#        'birdcage_birdcage_cage', 'birdcage_birdcage_bird',
#        'sit_next_stand', 'birdcage_birdcage_cage',
#        'birdcage_birdcage_bird', 'walking_walking_slowly',
#        'bridge_bridge_rope', 'walking_walking_walk', 'boy_boy_man',
#        'rest_grass_run', 'on_grass_over', 'lay_horse_fall',
#        'man_track_on', 'man_lay_in', 'lay_track_off', 'man_man_person',
#        'photograph_photograph_camera', 'dog_dog_girl', 'climb_climb_with',
#        'climb_climb_purple', 'climb_climb_hand', 'climb_climb_bare',
#        'climb_climb_hat', 'climb_climb_in', 'attend_classroom_full',
#        'classroom_attend_of', 'talk_talk_listen', 'at_recruit_to',
#        'shout_recruit_talk', 'bark_officer_at', 'at_stand_into',
#        'microphone_at_stage', 'microphone_at_on', 'microphone_at_sing',
#        'pencil_pencil_eyelid', 'pencil_pencil_apply', 'pencil_pencil_to',
#        'massage_woman_screw', 'man_woman_piece', 'woman_man_wood',
#        'woman_woman_wall', 'woman_woman_to', 'bird_wing_duck',
#        'fiercely_flap_with', 'fiercely_flap_green', 'water_on_in',
#        'flap_fiercely_head', 'bird_wing_brown', 'lay_lay_far',
#        'jump_jump_on', 'brown_tennis_ground', 'jump_jump_rest',
#        'show_small_next', 'dog_small_to', 'show_small_down',
#        'show_small_crouch', 'small_dog_at', 'show_show_sidewalk',
#        'show_dog_sit', 'woman_small_girl', 'show_small_little',
#        'show_dog_smile', 'show_small_on', 'paint_paint_clean',
#        'walk_walk_peel', 'along_terrain_across', 'walk_terrain_run',
#        'black_dog_white', 'terrain_walk_landscape', 'in_dirt_on',
#        'dirt_in_track', 'large_dog_fence', 'outside_in_sit',
#        'white_horse_dirty', 'hat_in_road', 'in_ride_on',
#        'green_field_park', 'lick_lick_with', 'lick_bottle_small',
#        'lick_lick_play', 'sit_hat_on', 'comb_comb_ruffle', 'ride_ride_in',
#        'ride_ride_black', 'ride_ride_do', 'wheel_wheel_motorbike',
#        'ride_ride_jacket', 'person_person_man', 'bicycle_bicycle_trick',
#        'wall_rope_mountain', 'run_try_play', 'try_run_toy', 'run_try_on',
#        'run_try_lawn', 'dog_two_cat', 'try_run_plastic', 'try_run_with',
#        'desert_area_wooded', 'high_jump_shade', 'jump_high_tree',
#        'high_jump_in', 'toddler_toddler_young', 'plastic_toy_wheeled',
#        'ride_ride_down', 'scooter_plastic_three', 'toddler_toddler_child',
#        'ride_ride_sidewalk', 'football_football_man',
#        'woman_woman_person', 'potato_potato_horse', 'fry_fry_cold',
#        'meat_meat_food', 'fry_fry_in', 'fry_fry_water', 'fry_fry_pot',
#        'fry_fry_place', 'flute_flute_guitar', 'rock_man_top',
#        'man_high_hiker', 'man_high_mountain', 'man_high_dance',
#        'onion_onion_potato', 'slice_slice_cut', 'walk_walk_past',
#        'walk_walk_park', 'walk_walk_with', 'walk_walk_bloom',
#        'walk_walk_lot', 'walk_walk_tree', 'woman_woman_man',
#        'walk_walk_wear', 'man_trick_old', 'man_trick_kid',
#        'trick_do_trick', 'throw_ceiling_down', 'throw_ceiling_take',
#        'throw_ceiling_from', 'smile_smile_bark', 'child_child_animal',
#        'underwater_swimming_ball', 'play_play_with', 'play_play_coat',
#        'play_play_white', 'dog_two_big', 'two_dog_small',
#        'tuxedo_two_little', 'two_red_boy', 'tuxedo_two_wear',
#        'rest_muzzle_race', 'muzzle_muzzle_on', 'muzzle_muzzle_nose',
#        'rest_muzzle_have', 'woman_woman_two', 'device_telephonic_phone',
#        'woman_woman_boy', 'camera_internet_webcam', 'talk_talk_in',
#        'man_girl_boy', 'talk_talk_teens', 'perform_perform_jump',
#        'huge_bubble_small', 'look_look_listen', 'look_look_front',
#        'look_look_class', 'look_look_at', 'look_look_attentively',
#        'classroom_direction_uniform', 'listen_class_ignore',
#        'shoot_shoot_row', 'race_race_on', 'race_race_track',
#        'horse_horse_dog', 'play_beach_run', 'play_beach_jump',
#        'on_play_along', 'two_dog_white', 'girl_father_child',
#        'father_girl_car', 'girl_father_small', 'father_girl_toy',
#        'father_girl_two', 'knife_knife_end', 'sharpen_sharpen_shave',
#        'knife_knife_pencil', 'woman_woman_man',
#        'octopus_octopus_instrument', 'woman_woman_monitor',
#        'look_man_wear', 'look_man_beige', 'man_look_in',
#        'woman_look_room', 'black_red_cloak', 'wear_wear_take',
#        'red_pink_large', 'wear_wear_revealing', 'dress_white_apparel',
#        'dress_black_extravagant', 'wear_wear_off', 'hand_hand_slide',
#        'girl_young_kid', 'hand_hand_arm', 'young_girl_blond',
#        'bmx_man_bike', 'participate_bmx_make', 'man_bmx_uniform',
#        'race_bmx_red', 'race_man_dirt', 'jump_jump_run',
#        'white_brown_little', 'animal_white_dog', 'sit_outside_play',
#        'belly_animal_back', 'woman_woman_man', 'electric_guitar_acoustic',
#        'take_take_man', 'take_take_sit', 'cheerleader_cheerleader_female',
#        'take_take_on', 'take_take_knee', 'score_score_miss',
#        'pizza_pizza_food', 'grass_grass_play', 'grass_grass_fall',
#        'football_boy_little', 'boy_foot_kid', 'grass_grass_into',
#        'man_man_guy', 'sit_sit_against', 'adult_five_people',
#        'sit_sit_wall', 'beach_beach_park', 'two_sumo_water',
#        'two_ringer_toy', 'ringer_two_man', 'man_man_dog', 'man_man_cat',
#        'wear_stand_for', 'wear_stand_pose', 'wear_stand_camera',
#        'wear_stand_for', 'wear_stand_pose', 'wear_stand_camera',
#        'crack_crack_to', 'crack_crack_talk', 'crack_crack_woman',
#        'eat_eat_peel', 'ride_orange_of', 'ride_raft_get', 'ride_raft_off',
#        'play_play_make', 'soda_can_drink', 'man_sunglass_table',
#        'front_soda_with', 'paint_paint_clean', 'man_snowboard_person',
#        'interview_interview_white', 'deny_deny_drive',
#        'interview_interview_car', 'run_chase_field', 'run_chase_dirt',
#        'ball_ball_tennis', 'dog_dog_white', 'run_chase_catch',
#        'ball_ball_dirty', 'run_chase_in', 'dog_dog_brown',
#        'play_play_slice', 'piano_piano_potato', 'field_field_gym',
#        'brown_dog_white', 'dog_brown_chase', 'dog_brown_two',
#        'run_run_walk', 'grass_grass_tall', 'garlic_garlic_ingredient',
#        'cut_cut_put', 'person_piece_wok', 'miss_grind_catch',
#        'jump_grind_off', 'tease_tease_pull', 'dog_dog_tail',
#        'plant_plant_cut', 'two_people_man', 'eat_eat_make',
#        'okra_okra_drum', 'empty_pool_in', 'man_man_jumper',
#        'catch_catch_bite', 'panda_panda_man', 'crouch_crouch_ledge',
#        'crouch_crouch_rusty', 'crouch_crouch_on', 'crouch_crouch_lean',
#        'dirt_run_track', 'run_run_alongside', 'large_run_fence',
#        'run_dirt_on', 'shrimp_shrimp_hair', 'boil_boil_comb',
#        'jacket_dog_blanket', 'run_jacket_through', 'jacket_run_grass',
#        'stand_stand_sniff', 'brown_grey_back', 'brown_grey_black',
#        'race_crowd_drag', 'two_car_come', 'two_car_of', 'two_car_out',
#        'race_crowd_flame', 'crowd_race_people', 'fish_immobile_swim',
#        'stand_front_climb', 'front_rock_with', 'man_man_skier',
#        'hill_snowy_bit', 'snowy_hill_tiny', 'hill_snowy_air',
#        'bottle_bottle_faucet', 'walk_baby_lick', 'electronic_man_device',
#        'hold_hold_up', 'motorbike_rider_relate', 'rider_motorbike_in',
#        'motorbike_rider_motocross', 'motorbike_rider_to',
#        'rider_motorbike_event', 'rider_motorbike_ride', 'in_jump_with',
#        'jump_bikini_play', 'bikini_jump_dune', 'people_people_woman',
#        'dance_dance_outside', 'brown_chase_grass', 'brown_chase_in',
#        'wear_run_with', 'shirt_wear_girl', 'man_two_friend',
#        'rise_rise_out', 'rise_rise_come', 'rise_rise_of',
#        'rise_rise_water', 'rise_rise_out', 'rise_rise_come',
#        'rise_rise_of', 'rise_rise_water', 'sing_dance_in',
#        'sing_dance_perform', 'sing_dance_rain', 'people_people_three',
#        'rope_bridge_wood', 'stream_rocky_river', 'girl_gymnastic_people',
#        'door_man_guitar', 'open_door_in', 'door_open_band',
#        'door_door_spotlight', 'open_door_play', 'man_man_bald',
#        'cyclist_jump_wall', 'cyclist_jump_bicyclist',
#        'cyclist_jump_trick', 'piano_play_on', 'cat_play_song',
#        'wait_wait_sit', 'sit_sit_stand', 'river_walk_shorts',
#        'river_walk_brown', 'boy_three_man', 'along_walk_in',
#        'along_walk_beside', 'slice_potato_slice', 'two_people_man',
#        'look_statue_outside', 'look_statue_play', 'at_look_near',
#        'people_two_young', 'gold_look_golden', 'man_carrot_climber',
#        'chase_grass_lose', 'grass_chase_on', 'make_bike_participate',
#        'dirt_race_in', 'bike_make_bmx', 'man_roof_player', 'man_roof_top',
#        'man_roof_violin', 'dance_roof_stand', 'roof_roof_over',
#        'guitar_guitar_dish', 'woman_young_man', 'guitar_guitar_dish',
#        'woman_young_man', 'man_yellow_standing', 'man_yellow_jacket',
#        'stand_canoe_wear', 'man_yellow_red', 'bare_bare_dash',
#        'hold_hold_rub', 'hold_hold_on', 'hold_hold_sit',
#        'hold_hold_chair', 'couch_couch_eye', 'untie_untie_tie',
#        'untie_untie_tie', 'person_person_man', 'sing_play_passionately',
#        'angel_snow_angel', 'child_two_people', 'snow_angel_snowsuit',
#        'draw_snow_make', 'midspeech_midspeech_back',
#        'midspeech_midspeech_on', 'hair_red_piercing',
#        'midspeech_midspeech_ear', 'red_eyebrow_have',
#        'midspeech_midspeech_tattoo', 'fly_near_swiftly',
#        'crane_white_bird', 'fly_water_off', 'near_water_from',
#        'fly_near_take', 'compete_compete_around', 'compete_compete_track',
#        'compete_compete_race', 'bird_wing_duck', 'wing_rest_with',
#        'wing_rest_head', 'rest_wing_flap', 'wing_rest_green',
#        'bird_wing_brown', 'river_walk_over', 'three_people_steel',
#        'put_amusedly_stand', 'water_water_shallow', 'small_two_young',
#        'small_people_adult', 'two_people_five', 'small_two_young',
#        'small_people_adult', 'two_people_five', 'fly_near_swiftly',
#        'crane_white_bird', 'fly_water_off', 'near_water_from',
#        'fly_near_take', 'man_man_woman', 'gun_gun_animal',
#        'coat_blue_world', 'blue_coat_new', 'boy_father_child',
#        'kid_kid_girl', 'kid_kid_four', 'kid_kid_middle', 'kid_kid_three',
#        'kid_kid_boy', 'kid_kid_eastern', 'kid_kid_child',
#        'fast_run_across', 'white_dog_small', 'run_fast_lawn',
#        'tug_wear_with', 'girl_two_boy', 'tug_wear_stick', 'two_girl_twin',
#        'tug_wear_duel', 'girl_two_preteen', 'family_child_man',
#        'child_family_kid', 'family_child_asian', 'child_family_three',
#        'hill_hill_up', 'hill_hill_up', 'chop_chop_ride',
#        'onion_onion_motorcycle', 'onion_onion_old', 'boy_boy_child',
#        'person_person_man', 'cut_cut_tie', 'rope_rope_thick',
#        'play_play_for', 'play_play_splash', 'play_play_background',
#        'play_play_in', 'slide_play_pool', 'child_play_kid',
#        'sit_next_stand', 'birdcage_birdcage_cage',
#        'birdcage_birdcage_bird', 'sit_next_stand',
#        'birdcage_birdcage_cage', 'birdcage_birdcage_bird',
#        'walk_puddle_wear', 'past_walk_in', 'walk_puddle_play',
#        'night_night_morning', 'cook_cook_fry', 'cat_small_dog',
#        'play_play_have', 'on_walk_in', 'on_walk_across', 'bridge_on_line',
#        'cut_cut_slice', 'garlic_garlic_onion', 'man_man_tiger',
#        'camera_camera_sound', 'man_man_cub', 'dog_brown_chase',
#        'cat_white_dog', 'women_women_woman', 'bunny_ear_pink',
#        'point_wear_right', 'point_wear_to', 'talk_cell_make',
#        'phone_cell_call', 'white_big_coat', 'piano_piano_potato',
#        'play_play_slice', 'pick_pick_slice', 'can_can_tomato',
#        'row_row_weapon', 'row_row_shoot', 'row_row_with',
#        'stand_gun_have', 'five_kid_none', 'next_woman_jump',
#        'sidewalk_sidewalk_curb', 'floor_floor_floor', 'floor_floor_sit',
#        'floor_floor_play', 'floor_floor_on', 'trot_trot_ride',
#        'horse_horse_motorcycle', 'girl_girl_man', 'horse_horse_wheel',
#        'stand_stand_sniff', 'brown_grey_back', 'brown_grey_black',
#        'walk_walk_peel', 'look_look_listen',
#        'classroom_direction_uniform', 'look_look_class', 'look_look_at',
#        'look_look_attentively', 'look_look_front', 'driver_race_person',
#        'hand_hand_helmet', 'hand_hand_colorful', 'yellow_dog_golden',
#        'dog_yellow_retriever', 'woman_shrimp_man', 'woman_shrimp_man',
#        'potato_potato_piano', 'slice_slice_play', 'stand_stand_sniff',
#        'big_grey_back', 'brown_grey_black', 'woman_woman_man',
#        'soda_sit_drink', 'sit_sit_wear', 'sit_sit_at', 'sit_soda_with',
#        'man_sit_table', 'place_place_dry', 'woman_two_people',
#        'skateboard_skateboard_do', 'girl_girl_skateboarder',
#        'carry_clumsily_hold', 'carry_clumsily_hand', 'shirt_two_size',
#        'shirt_two_sunglass', 'newspaper_two_large', 'clumsily_wear_in',
#        'bike_mountain_bicycle', 'do_do_with', 'do_do_only', 'do_do_wheel',
#        'do_do_ride', 'wall_rock_indoor', 'make_rock_climb',
#        'boy_young_child', 'uphill_run_up', 'man_man_woman',
#        'lady_lady_blonds', 'lady_lady_girl', 'man_man_woman',
#        'equipment_equipment_ponytail', 'hang_white_climb',
#        'vertical_rock_wall', 'woman_ball_man', 'woman_ball_man',
#        'wait_wait_stand', 'wait_wait_in', 'wait_wait_building',
#        'wait_wait_outside', 'wait_wait_fur', 'wait_wait_coat',
#        'wait_wait_hat', 'practice_practice_sell', 'person_person_lady',
#        'bark_officer_at', 'interview_interview_white',
#        'interview_interview_car', 'man_man_person', 'boy_boy_man',
#        'standing_dog_black', 'ball_soccer_jump', 'standing_dog_white',
#        'soccer_ball_for', 'three_look_hill', 'three_look_green',
#        'distance_look_in', 'three_look_big', 'look_look_at',
#        'look_look_stare', 'bridge_people_three', 'rope_bridge_wood',
#        'stream_rocky_river', 'noodle_noodle_woman',
#        'cyclist_cold_bicyclist', 'up_pick_drop', 'empty_empty_drop',
#        'empty_empty_carelessly', 'container_container_frog',
#        'dog_play_brown', 'play_dog_gray', 'man_man_woman', 'dog_two_egg',
#        'log_lie_on', 'steep_hill_street', 'great_dog_light',
#        'climb_climb_run', 'climb_climb_up', 'dog_great_brown',
#        'stand_stand_still', 'child_child_two', 'child_child_girl',
#        'child_child_kid', 'suit_swimming_bath', 'suit_swimming_wear',
#        'put_on_face', 'put_on_apply', 'on_put_to', 'woman_woman_girl',
#        'people_people_bird', 'people_people_white', 'butter_butter_prawn',
#        'man_man_woman', 'young_people_old', 'man_man_woman',
#        'bread_bread_herb', 'piano_piano_guitar', 'watch_rest_play',
#        'watch_child_spout', 'watch_spout_with', 'water_family_outdoors',
#        'man_man_racer', 'race_race_track', 'run_run_down',
#        'woman_woman_person', 'dry_dry_boil', 'people_people_woman',
#        'dance_dance_outside', 'play_rugby_on', 'field_play_muddy',
#        'man_man_young', 'man_man_rock', 'child_child_kid',
#        'play_play_splash', 'do_do_paint', 'look_look_die', 'do_do_on',
#        'man_shirt_dog', 'purple_funny_black', 'dog_animal_dog',
#        'man_man_bearded', 'sheep_herd_white', 'sheepdog_sheepdog_dog',
#        'herd_sheep_pack', 'group_group_scatter', 'man_man_woman',
#        'bread_bread_herb', 'stand_hold_seek', 'sign_cardboard_money',
#        'woman_woman_girl', 'horse_horse_motorbike', 'ride_ride_drive',
#        'man_mixing_mow', 'slice_slice_cut', 'garlic_cleave_capsicum',
#        'at_snap_with', 'snap_droplet_excitedly', 'snap_water_play',
#        'at_droplet_in', 'water_snap_grass', 'dance_dance_stand',
#        'dance_dance_on', 'dance_dance_leg', 'person_person_man',
#        'stand_stand_sit', 'stand_stand_sit', 'boy_little_rope',
#        'little_boy_attach', 'climb_wall_build', 'fearful_boy_up',
#        'wall_climb_artificially', 'boy_fearful_to',
#        'wall_climb_effortlessly', 'climb_fearful_climb',
#        'across_coat_across', 'in_coat_in', 'stand_stand_watch',
#        'stand_stand_laugh', 'stand_stand_breathlessly', 'girl_asian_two',
#        'slide_snow_slide', 'kid_slide_in', 'person_person_man',
#        'toy_toy_toy', 'run_toy_carry', 'mouth_mouth_grass',
#        'run_toy_color', 'cat_white_dog', 'street_cross_at',
#        'cross_street_stop', 'down_climb_out', 'ferrets_ferrets_ferret',
#        'climb_down_cage', 'down_climb_of', 'slice_slice_cut',
#        'garlic_cleave_capsicum', 'man_spitting_talk', 'ride_ride_play',
#        'mechanical_bull_keyboard', 'ride_ride_track', 'ride_ride_sandy',
#        'ride_ride_on', 'spar_spar_kickbox', 'woman_two_people',
#        'woman_people_spectator', 'piece_piece_cut', 'thin_lady_piece',
#        'oriental_cut_lady', 'laugh_laugh_spit', 'slide_snow_slide',
#        'kid_slide_in', 'walk_walk_restrain', 'oil_skillet_water',
#        'skillet_pour_oil', 'add_add_mix', 'add_add_cut', 'add_add_into',
#        'add_add_bowl', 'run_run_beach', 'run_run_on', 'woman_woman_man',
#        'violin_violin_piano', 'woman_woman_boy', 'oil_oil_piano',
#        'dog_monkey_at', 'monkey_dog_tease', 'dog_monkey_zoo',
#        'person_person_man', 'banana_banana_email', 'against_kid_on',
#        'ball_two_kid', 'colorful_against_ball', 'toy_car_sit',
#        'car_toy_red', 'car_toy_in', 'toy_car_yellow', 'girl_small_child',
#        'man_man_woman', 'violin_violin_onion', 'violin_violin_white',
#        'dog_pull_zoo', 'monkey_dog_tease', 'pull_dog_at',
#        'cover_cover_brown', 'cover_cover_with', 'cover_cover_smear',
#        'cover_cover_substance', 'mud_mud_background', 'comb_comb_ruffle',
#        'fetch_fetch_bite', 'dog_dog_black', 'dog_dog_small',
#        'dog_dog_white', 'fetch_fetch_swim', 'run_try_play', 'try_run_toy',
#        'try_run_with', 'run_try_lawn', 'dog_two_cat', 'try_run_plastic',
#        'run_try_on', 'toy_car_yellow', 'car_toy_in', 'car_toy_red',
#        'toy_car_sit', 'girl_small_child', 'tire_roll_tractor',
#        'roll_race_flip', 'man_two_people', 'play_play_intensely',
#        'girl_girl_man', 'take_take_dance', 'with_pose_without',
#        'broccoli_broccoli_tomato', 'woman_woman_man', 'man_child_young',
#        'kayake_kayake_ride', 'man_child_boy', 'surround_photographer_in',
#        'man_photographer_photographer', 'photographer_surround_suit',
#        'throw_throw_remove', 'throw_throw_from', 'throw_throw_tree',
#        'blade_blade_knife', 'man_boy_woman', 'rock_man_top',
#        'stand_stand_do', 'man_high_mountain', 'man_high_hiker',
#        'waterfall_beautiful_shallow', 'waterfall_beautiful_calmly',
#        'waterfall_beautiful_pool', 'waterfall_beautiful_into',
#        'beautiful_waterfall_flow', 'sit_area_busy', 'paint_cover_with',
#        'write_busy_wear', 'flute_flute_electronic',
#        'flute_flute_keyboard', 'girl_girl_child', 'walk_walk_down',
#        'walk_walk_down', 'blonde_sit_on', 'keyboard_keyboard_type',
#        'keyboard_keyboard_on', 'get_car_into', 'man_man_spit',
#        'man_jump_cyclist', 'launch_daughter_launch', 'snow_snow_forest',
#        'rider_rider_cyclist', 'wear_bike_at', 'wear_bike_day',
#        'snow_snow_snowy', 'put_away_play', 'birdcage_to_large',
#        'birdcage_next_colorful', 'to_next_beside',
#        'rodeo_bull_mechanical', 'woman_dancing_with',
#        'dancing_woman_sing', 'dancing_woman_dance', 'eat_eat_peel',
#        'harp_harp_violin', 'dirt_biker_two', 'biker_dirt_people',
#        'wear_wear_take', 'wear_wear_off', 'red_white_revealing',
#        'dress_black_extravagant', 'dress_white_apparel',
#        'black_red_cloak', 'red_pink_large', 'map_map_signboard',
#        'low_fence_cyclone', 'stand_hold_seek', 'sign_cardboard_money',
#        'pursue_turn_chase', 'dog_pursue_yellow', 'lift_lift_lower',
#        'lift_lift_lower', 'walk_walk_parade', 'walk_walk_wear',
#        'knee_wear_on', 'knee_hat_slide', 'wear_knee_have',
#        'white_white_black', 'crane_white_bird', 'fly_water_off',
#        'fly_near_take', 'near_water_from', 'fly_near_swiftly',
#        'with_hat_in', 'wooden_post_metallic', 'grind_gnaw_in',
#        'gnaw_grind_stick', 'mountain_snowy_hill', 'wall_wall_climb',
#        'woman_woman_pony', 'climb_climb_tail', 'bottle_yellow_guitar',
#        'man_woman_man', 'man_woman_man', 'man_man_woman',
#        'piano_piano_violin', 'hand_hand_man', 'play_play_run',
#        'play_play_grassy', 'play_play_through', 'brown_dog_furry',
#        'play_play_area', 'court_court_yard', 'peaceful_water_man',
#        'sail_sail_guitar', 'onion_onion_potato', 'slice_slice_cut',
#        'cat_black_dog', 'man_man_woman', 'pink_ear_women',
#        'man_man_woman', 'grass_ball_chase', 'grass_ball_on',
#        'eat_eat_season', 'black_dog_little', 'play_play_run',
#        'play_play_try', 'place_place_dry', 'hat_hat_pocket',
#        'store_store_market', 'hat_hat_cowboy', 'walk_walk_put',
#        'carry_run_carry', 'official_carry_rolling', 'carry_carry_past',
#        'naked_biker_wear', 'stand_blue_at', 'woman_woman_two',
#        'blue_blue_fancy', 'blue_stand_wear', 'white_dress_teens',
#        'stand_blue_event', 'woman_woman_girl', 'water_water_air',
#        'boy_young_kid', 'man_man_baby', 'cucumber_cucumber_rope',
#        'cucumber_cucumber_outside', 'slice_slice_jump', 'ride_raft_get',
#        'raft_ride_of', 'orange_ride_off', 'eat_eat_remove',
#        'banana_banana_peel', 'broccoli_broccoli_tomato',
#        'woman_woman_man', 'hold_hold_stand', 'violin_violin_harp',
#        'rest_river_walk', 'river_along_shorts', 'boy_three_man',
#        'river_rest_brown', 'along_river_beside', 'along_river_in',
#        'play_play_do', 'ride_ride_track', 'ride_ride_sandy',
#        'ride_ride_on', 'woman_woman_lady', 'hold_hold_slice',
#        'far_far_play', 'far_far_green', 'far_far_grass', 'far_far_on',
#        'ball_dog_small', 'woman_elderly_man', 'slice_slice_near',
#        'slice_slice_dance', 'slice_slice_fire', 'woman_girl_cat',
#        'little_girl_small', 'dog_dog_infant', 'smile_next_show',
#        'steep_hill_street', 'great_dog_light', 'climb_climb_run',
#        'climb_climb_up', 'dog_great_brown', 'costume_costume_scatter',
#        'costume_costume_look', 'woman_girl_people',
#        'costume_costume_wear', 'costume_costume_direction',
#        'costume_costume_different', 'costume_costume_forest',
#        'darkened_room_red', 'cyclist_cold_bicyclist',
#        'bread_pork_breaded', 'pork_fried_chop', 'chop_chop_fry',
#        'high_dog_jump', 'high_dog_in', 'dog_high_on', 'dog_high_tree',
#        'high_dog_shades', 'crouch_crouch_ledge', 'crouch_crouch_over',
#        'crouch_crouch_peer', 'crouch_crouch_rusty', 'dirt_biker_two',
#        'biker_dirt_people', 'off_fall_ride', 'little_boy_young',
#        'bicycle_bicycle_bike', 'race_race_helmet', 'talk_talk_dance',
#        'fetch_out_carry', 'dog_dog_black', 'dog_dog_swimming',
#        'dog_dog_small', 'dog_dog_white', 'spot_dog_on', 'play_dog_lie',
#        'black_brown_grey', 'play_dog_look', 'black_dog_silky',
#        'wade_wade_in', 'wade_wade_cold', 'wade_wade_stand',
#        'wade_wade_water', 'dog_dog_kid', 'toy_toy_dog', 'sit_sit_around',
#        'sit_sit_walk', 'do_barren_with', 'do_motorcycle_on',
#        'do_barren_film', 'experience_experience_fall',
#        'experience_experience_asleep', 'stand_play_in',
#        'young_play_shoulder', 'stand_play_sweater', 'girl_play_woman',
#        'play_stand_blue', 'pinwheel_pinwheel_hair',
#        'pinwheel_pinwheel_grey', 'stand_play_hold', 'stand_play_sit',
#        'stand_play_on', 'stand_play_in', 'young_play_shoulder',
#        'stand_play_sweater', 'girl_play_woman', 'play_stand_blue',
#        'pinwheel_pinwheel_hair', 'pinwheel_pinwheel_grey',
#        'stand_play_hold', 'stand_play_sit', 'stand_play_on',
#        'garlic_garlic_ingredient', 'man_man_person', 'man_makeup_face',
#        'put_man_paint', 'bike_bike_dirt', 'bike_bike_rider',
#        'put_put_poke', 'waste_bin_potato', 'baby_baby_hole',
#        'woman_rock_bay', 'woman_rock_man', 'rock_woman_city',
#        'rock_woman_climb', 'woman_rock_bay', 'woman_rock_man',
#        'rock_woman_city', 'rock_woman_climb', 'run_run_stand',
#        'run_run_still', 'sign_sign_charity', 'hold_beg_put',
#        'man_man_homeless', 'hold_beg_refuse', 'hold_beg_down',
#        'bicyclist_lone_cyclist', 'bicyclist_lone_cold',
#        'basketball_dunk_ball', 'basketball_dunk_game', 'dunk_dunk_at',
#        'dunk_dunk_jersey', 'player_crowd_man', 'dunk_dunk_with',
#        'place_place_cook', 'to_repeatedly_in', 'puppy_puppy_animal',
#        'repeatedly_to_garden', 'to_repeatedly_from', 'stand_play_in',
#        'play_stand_away', 'play_stand_case', 'stand_play_put',
#        'dog_dog_show', 'dog_dog_infant', 'man_little_woman',
#        'dog_dog_small', 'wear_stand_for', 'wear_stand_pose',
#        'wear_stand_camera', 'wear_stand_for', 'wear_stand_pose',
#        'wear_stand_camera', 'person_painting_draw', 'leave_stage_perform',
#        'leave_stage_on', 'pebbly_beach_sandy', 'golden_golden_two',
#        'dog_small_cat', 'white_horse_dirty', 'hat_in_road', 'in_ride_on',
#        'pizza_pizza_food', 'across_grass_on', 'across_grass_with',
#        'across_grass_tennis', 'wooden_stand_together', 'wooden_stand_kid',
#        'kitten_kitten_food', 'crowd_large_gathering', 'large_crowd_man',
#        'crowd_large_boy', 'crowd_large_people', 'crowd_large_young',
#        'crowd_large_front', 'crowd_large_woman', 'crowd_large_two',
#        'woman_woman_person', 'seadoo_seadoo_jetskus',
#        'woman_woman_frying', 'shoot_shoot_row',
#        'photographer_photographer_man', 'suit_wear_in', 'man_man_woman',
#        'work_work_with', 'work_work_mouse', 'work_work_feed',
#        'brown_coat_furry', 'brown_coat_through', 'brown_coat_area',
#        'brown_coat_grassy', 'coat_brown_dog', 'brown_coat_run',
#        'run_run_slow', 'white_dog_little', 'run_run_down',
#        'person_black_owner', 'two_people_animal', 'play_play_water',
#        'play_play_in', 'man_three_woman', 'man_three_woman',
#        'cooking_fish_frying', 'slowly_walk_quickly', 'walk_slowly_run',
#        'slowly_walk_quickly', 'walk_slowly_run', 'potato_potato_onion',
#        'cut_cut_slice', 'toddler_two_kid', 'sleep_sleep_eat',
#        'toddler_two_young', 'okra_okra_cooking', 'beach_pull_at',
#        'leash_pull_dog', 'pull_beach_stand', 'beach_pull_with',
#        'put_put_poke', 'waste_bin_potato', 'baby_baby_hole',
#        'walk_walk_in', 'walk_walk_rain', 'jump_snow_catch',
#        'frisbee_dog_black', 'snow_jump_off', 'snow_jump_in',
#        'snow_jump_ground', 'jump_snow_leap', 'walk_walk_peel',
#        'song_guitar_headphone', 'man_man_package', 'play_sing_open',
#        'quickly_quickly_up', 'horse_blue_towards', 'panda_panda_man',
#        'put_man_paint', 'makeup_man_face', 'two_people_man',
#        'run_run_carry', 'run_run_into', 'player_run_official',
#        'stand_stand_watch', 'stand_stand_laugh', 'girl_asian_two',
#        'white_dog_small', 'interview_interview_white',
#        'grant_grant_drive', 'interview_interview_car',
#        'man_man_guitarist', 'guitar_guitar_flyaway', 'guitar_guitar_hair',
#        'guitar_guitar_blonde', 'horse_horse_desert', 'horse_horse_in',
#        'woman_woman_two', 'woman_woman_people', 'run_run_carry',
#        'run_run_past', 'player_ball_person', 'run_ball_official',
#        'player_football_playing', 'surfer_surfer_man', 'wave_wave_shoe',
#        'man_vegetable_person', 'mix_pot_stir', 'mix_pot_in',
#        'in_play_from', 'play_swim_out', 'play_crocodile_take',
#        'dog_dog_kid', 'toy_toy_dog', 'phone_phone_sing', 'phone_phone_to',
#        'phone_phone_woman', 'screw_screw_massage', 'put_amusedly_stand',
#        'water_water_shallow', 'on_walk_in', 'on_walk_across',
#        'bridge_on_line', 'child_child_boy', 'world_new_coat',
#        'child_child_father', 'look_look_in', 'look_look_stream',
#        'look_look_play', 'man_hat_woman', 'wear_hat_look', 'white_hat_in',
#        'wear_wear_red', 'white_wear_side', 'hat_wear_to',
#        'white_hat_with', 'white_wear_brown', 'white_wear_behind',
#        'hat_wear_shirt', 'up_sit_from', 'worker_sit_man', 'sit_up_take',
#        'man_man_cat', 'place_place_fry', 'food_food_meat',
#        'play_play_slice', 'piano_piano_potato', 'woman_woman_two',
#        'blue_blue_fancy', 'blue_blue_at', 'blue_blue_wear',
#        'woman_woman_teenage', 'blue_blue_event', 'woman_woman_girl',
#        'orange_pepper_bell', 'person_person_cook', 'dice_up_slice',
#        'man_three_man', 'dance_dance_look', 'water_walk_deep',
#        'through_walk_in', 'walk_through_swim', 'white_horse_woman',
#        'man_man_climb', 'man_man_young', 'man_man_rock',
#        'run_on_difficultly', 'large_tennis_gray', 'on_run_across',
#        'run_grass_carry', 'keyboard_keyboard_type',
#        'keyboard_keyboard_on', 'guitar_guitar_sing',
#        'guitar_guitar_acoustic', 'in_dirt_on', 'dirt_in_track',
#        'large_dog_fence', 'outside_in_sit', 'brown_toy_across',
#        'grass_grass_mouth', 'toy_dog_with', 'toy_carry_yard',
#        'carry_toy_run', 'email_email_banana', 'man_man_person',
#        'football_football_man', 'play_man_hold', 'football_man_man',
#        'place_place_frying', 'food_food_meat', 'bird_wing_duck',
#        'rest_rest_with', 'rest_rest_green', 'rest_rest_flap',
#        'rest_rest_head', 'bird_wing_brown', 'of_flow_into',
#        'fun_fun_card', 'fun_fun_trick', 'have_have_do',
#        'grass_grass_play', 'grass_grass_fall', 'football_boy_little',
#        'boy_foot_kid', 'grass_grass_into', 'cheer_cheer_perform',
#        'with_jump_over', 'with_green_without', 'green_with_grass',
#        'family_tree_happy', 'mantel_christmas_fireplace',
#        'kitten_kitten_small', 'milk_milk_cup', 'kitten_kitten_child',
#        'guitar_guitar_piano', 'boy_young_kid', 'man_boy_amphitheater',
#        'man_boy_adult', 'hold_carelessly_drop', 'small_stick_huge',
#        'on_sit_from', 'sit_on_take', 'trick_trick_bicycle',
#        'motorbike_motorbike_wheel', 'do_do_ride', 'jump_jump_run',
#        'sidewalk_sidewalk_road', 'white_dog_little', 'sit_sit_grass',
#        'sit_sit_wear', 'sit_sit_on', 'man_man_person', 'walk_water_out',
#        'in_walk_of', 'guitar_guitar_girl', 'guitar_guitar_player',
#        'empty_pool_in', 'man_man_jumper', 'at_snap_with',
#        'snap_droplet_excitedly', 'snap_water_play', 'at_droplet_in',
#        'water_snap_grass', 'person_person_man',
#        'motorbike_motorbike_barbell', 'player_intense_play',
#        'piano_piano_guitar', 'stand_still_dance', 'man_two_friend',
#        'cut_cut_with', 'cut_cut_scissors', 'high_jump_in',
#        'high_jump_air', 'person_person_young', 'green_shirt_knee',
#        'person_person_boy', 'green_shirt_bend', 'person_person_arm',
#        'raise_arm_in', 'cut_cut_slice', 'garlic_garlic_onion',
#        'adult_five_people', 'jump_snow_catch', 'frisbee_dog_black',
#        'snow_jump_grind', 'snow_jump_off', 'snow_jump_in',
#        'jump_snow_leap', 'into_car_in', 'man_gymnastic_people',
#        'bounce_bounce_wear', 'boy_boy_girl', 'drinking_kitten_drink',
#        'ride_ride_drinking', 'elephant_elephant_soda', 'ride_ride_open',
#        'hold_hold_stand', 'hold_hold_near', 'hold_hold_use',
#        'hold_fishing_tool', 'hold_hold_for', 'hold_hold_water',
#        'burn_burn_repair', 'man_man_woman', 'guitar_guitar_drum',
#        'sit_sit_front', 'sit_sit_restaurant', 'sit_sit_in',
#        'side_building_top', 'stand_hold_seek', 'sign_cardboard_money',
#        'clean_clean_prepare', 'fish_fish_garlic', 'slice_slice_chop',
#        'hunt_fish_follow', 'swimmer_swimmer_swimmers', 'jump_jump_do',
#        'skateboarder_skateboarder_trick', 'air_air_shirt', 'air_air_red',
#        'skateboarder_skateboarder_man', 'rock_man_city', 'man_rock_bay',
#        'man_rock_person', 'jump_jump_trampoline', 'clothes_red_outfit',
#        'boy_little_child', 'jump_jump_on', 'jump_jump_dangerously',
#        'play_play_approach', 'two_dog_black', 'two_dog_golden',
#        'beach_beach_pebbly', 'onion_onion_foot', 'chop_chop_wash',
#        'boy_small_topless', 'small_boy_serious', 'small_boy_little',
#        'talk_talk_crack', 'look_look_play', 'look_look_river',
#        'look_look_in', 'brown_dog_golden', 'green_grass_field',
#        'woman_woman_man', 'carefully_debon_catch', 'play_wear_toy',
#        'wear_play_indoor', 'wear_play_with', 'top_mountain_rock',
#        'top_mountain_stand', 'hiker_mountain_tree', 'top_mountain_above',
#        'mountain_top_in', 'top_mountain_high', 'hiker_hiker_man',
#        'white_white_girl', 'white_white_two', 'woman_woman_fancy',
#        'woman_woman_dress', 'white_white_teenage',
#        'car_pedestrians_vehicle', 'pedestrians_car_people',
#        'scooter_scooter_tree', 'scooter_scooter_small',
#        'girl_little_elephant', 'girl_little_baby', 'child_child_wear',
#        'green_of_black', 'jeep_of_hill', 'of_green_to', 'green_of_dirt',
#        'of_jeep_on', 'stand_of_next', 'man_man_woman', 'hold_hold_handle',
#        'dog_dog_cat', 'jump_jump_on', 'jump_jump_grind', 'jump_jump_rest',
#        'boy_boy_woman', 'wooden_block_in', 'block_wooden_blue',
#        'wooden_block_on', 'block_wooden_look', 'wooden_block_hand',
#        'wooden_block_near', 'wooden_block_shirt', 'block_wooden_at',
#        'block_wooden_table', 'block_wooden_stack',
#        'flute_flute_electronic', 'flute_flute_keyboard', 'ride_ride_dirt',
#        'ride_ride_on', 'ride_ride_road', 'jump_jump_into',
#        'jump_jump_air', 'set_set_rise', 'walk_across_stand',
#        'across_walk_in', 'set_set_rise', 'walk_across_stand',
#        'across_walk_in', 'put_away_lean', 'away_put_wall',
#        'dress_red_costume', 'away_put_brick', 'put_away_play',
#        'away_put_against', 'shun_shun_with', 'shun_shun_around',
#        'shun_shun_walk', 'shun_shun_pen', 'shun_shun_mother',
#        'walk_walk_wade', 'water_water_marsh', 'onion_onion_dish',
#        'woman_woman_man', 'woman_baby_hole', 'waste_bin_potato',
#        'put_baby_poke', 'potato_potato_piano', 'slice_slice_play',
#        'white_puppy_brown', 'crowd_crowd_people', 'watch_watch_run',
#        'watch_watch_play', 'watch_watch_in', 'watch_watch_field',
#        'man_man_wall', 'man_man_a', 'worker_construction_man',
#        'sit_up_take', 'two_construction_break', 'ride_ride_play',
#        'mechanical_bull_keyboard', 'across_grass_on', 'large_ball_size',
#        'across_grass_with', 'across_grass_tennis', 'at_waterfall_near',
#        'man_water_body', 'stand_stand_swim', 'slice_slice_up',
#        'pepper_bell_orange', 'cook_cook_person', 'slice_slice_dice',
#        'hit_hit_miss', 'hit_hit_miss', 'play_play_drop', 'up_wrap_cut',
#        'stand_people_carnival', 'group_group_stand', 'young_with_front',
#        'young_ball_four', 'pose_with_kneel', 'with_pose_to',
#        'pose_with_next', 'with_pose_in', 'eggs_eggs_two', 'eggs_eggs_egg',
#        'boil_boil_place', 'boil_boil_water', 'boil_boil_pot',
#        'boil_boil_into', 'boy_boy_little', 'boy_boy_girl',
#        'band_band_man', 'instrument_instrument_keyboard',
#        'instrument_instrument_electronic', 'man_man_woman',
#        'slice_slice_peel', 'rock_wall_indoor', 'make_make_climb',
#        'climber_young_child', 'stand_hold_seek', 'sign_cardboard_money',
#        'soaker_super_onion', 'man_man_person', 'woman_woman_man',
#        'dance_dance_stand', 'top_mountain_rock',
#        'dance_dance_uncomfortable', 'dance_dance_in',
#        'top_mountain_above', 'dance_dance_position', 'top_mountain_high',
#        'top_mountain_tree', 'hiker_hiker_man', 'go_water_come',
#        'go_water_of', 'go_water_out', 'go_water_come', 'go_water_of',
#        'go_water_out', 'woman_woman_bicyclist', 'tree_small_scooter',
#        'elephant_baby_little', 'baby_elephant_girl',
#        'earring_young_smile', 'sweatshirt_necklace_with',
#        'earring_wear_upon', 'sweatshirt_necklace_suit', 'high_jump_shade',
#        'jump_high_tree', 'high_jump_in', 'piece_piece_cut',
#        'oriental_piece_lady', 'piece_lady_piece', 'piece_piece_into',
#        'potato_potato_onion', 'cut_cut_slice', 'kid_two_child',
#        'woman_woman_man', 'sit_sit_down', 'boy_boy_toddler',
#        'lean_sharp_go', 'into_lean_around',
#        'motorcyclist_motorcyclist_man', 'bike_bike_motorcycle',
#        'lounge_lounge_exercise', 'girl_girl_boy', 'girl_girl_boy',
#        'shrimp_shrimp_animal', 'football_two_basketball',
#        'court_court_floor', 'ball_ball_grab', 'kid_kid_boy',
#        'on_sit_across', 'sit_on_walk', 'on_bridge_in', 'bridge_sit_line',
#        'man_man_person', 'man_man_rock', 'rope_rope_pink',
#        'man_man_front', 'black_dog_white', 'car_traffic_man',
#        'run_run_past', 'run_ball_official', 'run_run_carry',
#        'team_two_player', 'man_man_woman', 'front_waterfall_look',
#        'in_in_front', 'front_sit_at', 'rest_rest_run', 'rest_rest_in',
#        'rest_rest_circle', 'ignore_girl_to', 'via_camera_with',
#        'ignore_girl_talk', 'operate_camera_with', 'video_video_subject',
#        'operate_camera_study', 'sprinkle_sprinkle_put',
#        'cheese_shred_season', 'pen_whole_pace', 'tire_whole_tiredly',
#        'pen_whole_in', 'woman_woman_piece', 'massage_massage_screw',
#        'massage_massage_to', 'massage_massage_wall', 'woman_woman_wood',
#        'rest_rest_flap', 'in_water_on', 'food_food_skunk', 'fry_fry_hold',
#        'butter_butter_tofu', 'use_use_play', 'stand_stand_sniff',
#        'big_grey_back', 'brown_grey_black', 'crawl_baby_cheer',
#        'play_play_face', 'play_play_in', 'dog_black_two',
#        'dog_play_kennel', 'play_play_hind', 'play_play_on',
#        'play_play_leg', 'baby_baby_hole', 'waste_bin_potato',
#        'put_put_poke', 'play_play_wear', 'child_child_young',
#        'play_play_drop', 'woman_woman_man', 'electric_guitar_acoustic',
#        'children_children_kid', 'children_children_three',
#        'play_play_jump', 'dog_white_lady', 'sunny_day_rainy',
#        'kid_kid_girl', 'kid_kid_four', 'kid_kid_middle', 'kid_kid_three',
#        'kid_kid_boy', 'kid_kid_eastern', 'kid_kid_child', 'man_man_boy',
#        'cereal_cereal_arm', 'cereal_cereal_float', 'man_man_girl',
#        'take_take_knee', 'take_take_sit',
#        'cheerleader_cheerleader_female', 'take_take_on', 'take_take_man',
#        'kid_green_boy', 'young_kid_four', 'young_kid_front',
#        'hold_hold_toward', 'woman_man_couple', 'hold_hold_ocean',
#        'man_man_woman', 'stand_wear_in', 'jersey_stand_black',
#        'toy_ride_of', 'toy_car_out', 'ride_car_get',
#        'animal_small_person', 'girl_girl_boy', 'stop_stop_run',
#        'post_back_pole', 'woman_lamp_people', 'woman_post_man',
#        'post_back_pole', 'woman_lamp_people', 'woman_post_man',
#        'oil_skillet_water', 'skillet_pour_oil', 'scare_baby_cheer',
#        'show_off_hand', 'small_monkey_big', 'show_off_in',
#        'monkey_small_animal', 'show_off_hold', 'city_city_small',
#        'sign_sign_charity', 'sign_sign_work', 'hold_beg_do',
#        'box_box_guitar', 'open_open_play', 'walk_walk_parade',
#        'walk_walk_wear', 'keyboard_play_on', 'keyboard_play_piano',
#        'keyboard_cat_song', 'play_play_idle', 'cyclist_cold_bicyclist',
#        'blanket_blue_muzzle', 'run_run_rest', 'run_run_in',
#        'blanket_blue_jacket', 'run_run_yard', 'person_person_man',
#        'sing_play_passionately', 'sidewalk_sidewalk_road',
#        'jump_jump_run', 'white_dog_little', 'zucchini_zucchini_vegetable',
# ...
#        'guitar_guitar_hair', 'guitar_guitar_flyaway', 'play_play_have',
#        'ride_ride_dirt', 'ride_ride_road', 'ride_ride_on',
#        'purple_shirt_black', 'chap_stand_camera', 'shirt_purple_wear',
#        'leather_chap_pose', 'leather_chap_for', 'player_player_two',
#        'player_player_team', 'talk_talk_eat', 'talk_talk_happily',
#        'couch_couch_beach', 'sit_crochet_play', 'reload_reload_fire',
#        'fountain_jump_front', 'behind_jump_in', 'man_man_dog',
#        'run_run_breathlessly', 'two_ringer_toy', 'ringer_two_man',
#        'two_sumo_water', 'bubble_bubble_huge', 'girl_girl_young',
#        'punch_punch_mix', 'ball_soccer_bowl', 'soccer_ball_content',
#        'swimming_smile_pool', 'swimming_smile_swim', 'swimming_smile_in',
#        'person_person_woman', 'horse_horse_potato', 'toy_toy_ball',
#        'baby_baby_tiger', 'guitar_guitar_piano', 'fish_fish_follow',
#        'woman_woman_down', 'peel_peel_refrigerate', 'toy_car_through',
#        'car_toy_run', 'car_toy_chase', 'child_small_dog', 'toy_car_field',
#        'wear_shirt_under', 'girl_girl_little', 'girl_girl_boy',
#        'pink_wear_tree', 'pink_wear_in', 'shirt_wear_desert',
#        'in_pen_outside', 'person_bike_accident', 'bike_bike_rider',
#        'woman_woman_man', 'play_play_down', 'play_play_lay',
#        'electric_guitar_drink', 'man_man_people', 'boy_rock_male',
#        'cliff_boy_edge', 'rock_cliff_two', 'large_ball_big',
#        'hit_hit_miss', 'child_child_crowd', 'child_child_people',
#        'red_have_midspeech', 'hair_eyebrow_in', 'have_eyebrow_with',
#        'red_eyebrow_and', 'small_child_young', 'walk_through_splash',
#        'through_walk_in', 'woman_woman_man', 'dog_scold_with',
#        'scold_dog_play', 'grass_grass_bike', 'graze_graze_sit',
#        'grass_grass_police', 'animal_animal_cop', 'sunny_day_hot',
#        'hike_hike_walk', 'scout_scout_explorer', 'woman_woman_man',
#        'play_play_lay', 'play_play_down', 'eat_eat_toy', 'eat_eat_with',
#        'eat_eat_play', 'out_climb_from', 'climb_out_shelf',
#        'out_climb_down', 'ferret_ferret_ferrets', 'sing_dance_rain',
#        'sing_dance_in', 'hike_hike_walk', 'scout_scout_explorer',
#        'knife_tree_bike', 'at_dangerously_with', 'at_tree_against',
#        'man_man_dangerous', 'kick_kick_practice', 'take_reveal_put',
#        'reveal_take_conceal', 'off_take_on', 'man_large_veteran',
#        'man_large_thing', 'large_man_war', 'large_man_different',
#        'driver_car_motionless', 'up_stand_down', 'stand_point_sit',
#        'driver_car_motionless', 'up_stand_down', 'stand_point_sit',
#        'boy_blue_child', 'blow_by_set', 'by_camera_to', 'man_draw_woman',
#        'white_white_dance', 'in_pen_outside', 'cliff_cliff_rock',
#        'rope_rope_climb', 'rope_rope_pink', 'climb_climb_rope',
#        'rope_rope_gear', 'man_man_person', 'cub_tiger_baby',
#        'ball_ball_doll', 'jump_off_run', 'man_three_young',
#        'jump_off_kick', 'off_jump_furiously', 'jump_off_vend',
#        'jump_off_machine', 'off_jump_near', 'remove_from_throw',
#        'from_remove_at', 'potato_potato_carrot', 'blow_by_set',
#        'by_camera_to', 'dog_white_tree', 'dog_white_on',
#        'white_dog_stump', 'white_dog_sit', 'jump_jump_back',
#        'jump_jump_flip', 'boy_boy_man', 'jump_jump_do', 'outside_ball_in',
#        'ball_ball_soccer', 'play_outside_field', 'dog_dog_grey',
#        'outside_ball_on', 'ball_play_head', 'outside_ball_bounce',
#        'ball_outside_grass', 'man_man_little', 'man_man_girl',
#        'pursue_turn_chase', 'dog_dog_yellow', 'girl_girl_man',
#        'couch_couch_beach', 'sit_crochet_play',
#        'cosmetic_cosmetic_pencil', 'cosmetic_cosmetic_liner',
#        'cosmetic_cosmetic_eye', 'apply_apply_use', 'carrot_carrot_pork',
#        'away_put_coat', 'carrot_carrot_chop', 'person_person_accident',
#        'bike_person_rider', 'wheelie_wheelie_motorcycle',
#        'catch_friend_drive', 'friend_friend_in', 'friend_friend_dress',
#        'wheelie_friend_rider', 'black_black_wheel',
#        'friend_friend_orange', 'dance_dance_pray',
#        'dance_dance_fervently', 'uniform_woman_vest', 'wear_keep_march',
#        'uniform_woman_cap', 'uniform_woman_shirt', 'keep_wear_talk',
#        'two_dog_together', 'with_christmas_near', 'white_headband_ear',
#        'white_christmas_reindeer', 'player_player_two',
#        'player_player_team', 'trek_trek_hike', 'pack_pack_sing',
#        'pack_pack_play', 'do_do_in', 'pull_pull_dash', 'do_do_gym',
#        'player_player_green', 'ball_soccer_kick', 'player_player_man',
#        'up_look_down', 'friend_friend_dress',
#        'wheelie_wheelie_motorcycle', 'catch_friend_drive',
#        'friend_friend_in', 'wheelie_friend_rider', 'black_black_wheel',
#        'friend_friend_orange', 'chop_chop_cook', 'bread_pork_breaded',
#        'pork_bread_chop', 'white_stage_hat', 'stage_stage_stage',
#        'stage_stage_on', 'stage_stage_in', 'stage_stage_play',
#        'man_table_dim', 'woman_two_people', 'baseball_baseball_drop',
#        'baseball_baseball_from', 'white_dog_black', 'man_man_scare',
#        'ball_ball_in', 'ball_ball_blue', 'ball_ball_mouth',
#        'run_ball_carry', 'dog_dog_black', 'ball_ball_white',
#        'sit_man_front', 'in_sit_in', 'in_sit_stand', 'sit_man_front',
#        'in_sit_in', 'in_sit_stand', 'car_toy_train', 'strike_toy_miss',
#        'tap_tap_rest', 'guitar_guitar_flute', 'adult_adult_man',
#        'guitar_guitar_piano', 'red_big_blue', 'child_child_toddler',
#        'child_child_splash', 'red_pool_inside', 'pool_red_paddling',
#        'sweater_pink_grassy', 'staircase_concrete_step',
#        'little_child_small', 'child_little_outdoors', 'sweater_pink_area',
#        'man_man_woman', 'bun_bun_tomato', 'spot_white_nap',
#        'talk_talk_spit', 'water_shallow_through', 'kid_kid_boy',
#        'water_shallow_beach', 'water_shallow_at', 'water_shallow_run',
#        'boy_boy_man', 'boy_boy_flip', 'throw_away_play', 'kid_kid_boy',
#        'kid_kid_young', 'instrument_instrument_wind', 'man_box_karate',
#        'man_box_practitioner', 'box_kick_glove', 'box_man_protective',
#        'car_park_into', 'park_car_get', 'piano_piano_guitar',
#        'play_play_sing', 'boy_boy_man', 'boy_blue_child',
#        'comb_comb_arrange', 'water_water_sea', 'man_man_person',
#        'woman_woman_man', 'horse_horse_headphone', 'woman_woman_small',
#        'woman_woman_package', 'sit_sit_front', 'sit_sit_restaurant',
#        'sit_sit_in', 'ride_paddle_float', 'raft_ride_on',
#        'people_people_four', 'boy_air_person', 'bent_knee_shirt',
#        'bent_knee_green', 'vegetable_vegetable_tomato',
#        'person_person_woman', 'bee_bee_small', 'yellow_flower_bunch',
#        'bee_bee_landing', 'yellow_flower_on', 'toy_car_train',
#        'strike_toy_miss', 'cliff_cliff_rock', 'rope_rope_climb',
#        'rope_rope_pink', 'climb_climb_rope', 'rope_rope_gear',
#        'man_man_person', 'boat_boat_man', 'man_man_woman',
#        'head_hold_over', 'hold_head_people', 'hold_bike_with',
#        'slice_slice_not', 'slice_slice_cut', 'old_topless_young',
#        'shrimp_shrimp_butter', 'woman_woman_man', 'water_water_grass',
#        'water_water_high', 'stand_stand_chop', 'lady_blonde_woman',
#        'tower_tower_view', 'tower_tower_city', 'boy_adult_to',
#        'adult_boy_talk', 'mix_mix_separate', 'man_man_woman',
#        'wood_leap_in', 'wood_leap_area', 'car_car_watch',
#        'flame_people_crowd', 'car_car_leave', 'car_car_racing',
#        'car_car_two', 'carrot_carrot_pork', 'woman_woman_cook',
#        'carrot_carrot_chop', 'kick_kick_practice', 'door_door_onion',
#        'open_open_cut', 'potato_potato_carrot', 'wear_wear_break',
#        'punch_punch_mix', 'ball_soccer_bowl', 'soccer_ball_content',
#        'boat_boat_man', 'have_leap_over', 'have_leap_barrier',
#        'track_track_color', 'track_track_red', 'track_track_blue',
#        'horse_horse_toss', 'track_track_pants', 'track_track_cowboy',
#        'track_track_wear', 'sticky_goo_pasta', 'out_pull_into',
#        'pull_out_dish', 'pull_out_put', 'meat_meat_mixer',
#        'slice_meat_crack', 'lady_meat_egg', 'meat_meat_for',
#        'look_full_front', 'attentively_look_at',
#        'classroom_direction_uniform', 'attentively_student_listen',
#        'student_attentively_class', 'vegetable_vegetable_tomato',
#        'tap_tap_table', 'tap_tap_on', 'tap_tap_rest', 'small_child_young',
#        'walk_through_splash', 'through_walk_in', 'burn_burn_to',
#        'person_person_tall', 'burn_burn_set', 'camera_burn_fire',
#        'person_person_man', 'rock_rock_cliff', 'cook_cook_man',
#        'scatter_scatter_herd', 'floor_floor_floor', 'floor_floor_sit',
#        'floor_floor_in', 'floor_floor_room', 'floor_floor_strum',
#        'floor_floor_on', 'talk_microphone_talk', 'front_parrot_into',
#        'water_water_pitcher', 'woman_tap_boy', 'jump_jump_tree',
#        'jump_jump_in', 'jump_jump_shade', 'fountain_jump_front',
#        'behind_jump_in', 'person_person_athlete', 'jacket_pink_stadium',
#        'run_run_woman', 'jacket_pink_crowd', 'person_person_four',
#        'run_run_with', 'camera_picture_lake', 'fish_fish_follow',
#        'dog_dog_black', 'near_walk_in', 'child_excitement_woman',
#        'small_child_little', 'child_excitement_girl', 'walk_walk_lazily',
#        'walk_walk_down', 'wave_wave_at', 'lady_lady_girl',
#        'lady_lady_blond', 'wave_wave_look', 'little_boy_laugh',
#        'tank_laugh_in', 'red_pool_inside', 'water_water_splash',
#        'red_pool_make', 'pool_red_paddling', 'child_child_toddler',
#        'red_big_blue', 'play_play_with', 'flute_flute_game',
#        'play_play_ball', 'do_do_in', 'pull_pull_dash', 'do_do_gym',
#        'man_man_boy', 'ginger_ginger_onion', 'cut_cut_slice',
#        'hold_hold_crowd', 'hold_hold_look', 'hold_hold_people',
#        'woman_asian_elegant', 'hold_hold_down', 'hold_hold_inside',
#        'horse_horse_knock', 'horse_horse_off', 'horse_horse_of',
#        'white_building_black', 'tan_run_spot', 'tan_run_beige',
#        'tan_dog_white', 'brush_brush_field', 'run_run_with',
#        'play_alone_walk', 'alone_play_along', 'alone_play_snowdrift',
#        'child_small_woman', 'small_child_little', 'child_small_girl',
#        'swimsuit_red_shorts', 'pool_kiddie_paddling', 'child_child_crowd',
#        'child_child_people', 'scatter_scatter_herd', 'miss_miss_knock',
#        'hold_hold_squat', 'afghan_rainbow_photo', 'hold_hold_take',
#        'girl_girl_man', 'purple_purple_brush', 'player_player_man',
#        'ball_soccer_kick', 'soccer_ball_green', 'soccer_ball_in',
#        'eat_eat_make', 'sing_dance_with', 'comb_comb_arrange',
#        'happily_slide_hat', 'slide_happily_on', 'happily_slide_jacket',
#        'slide_happily_knee', 'happily_slide_wear', 'happily_slide_hill',
#        'slide_happily_black', 'kid_kid_boy', 'slide_happily_red',
#        'slide_happily_cover', 'car_park_into', 'park_car_get',
#        'lie_woman_lie', 'read_lie_rock', 'lie_read_over',
#        'in_leave_through', 'leave_dirt_chase', 'front_hut_in',
#        'in_in_front', 'person_person_skilled', 'trick_trick_bicycle',
#        'motorbike_motorbike_wheel', 'do_do_ride', 'carry_carry_jersey',
#        'carry_carry_with', 'carry_carry_run', 'carry_carry_touchdown',
#        'carry_carry_in', 'carry_carry_purple', 'carry_carry_ball',
#        'carry_carry_for', 'ride_ride_dirt', 'ride_ride_road',
#        'ride_ride_on', 'put_away_up', 'put_away_chop', 'hold_in_drop',
#        'in_hold_from', 'white_dog_black', 'kick_kick_practice',
#        'restaurant_restaurant_without', 'restaurant_restaurant_red',
#        'restaurant_restaurant_table', 'restaurant_restaurant_in',
#        'restaurant_restaurant_light', 'water_shallow_through',
#        'water_shallow_at', 'water_shallow_beach', 'kid_kid_boy',
#        'water_shallow_run', 'golden_golden_two', 'pebbly_beach_rocky',
#        'area_child_grassy', 'swim_underwater_in', 'swim_underwater_pool',
#        'race_drag_two', 'flame_people_crowd', 'race_drag_watch',
#        'race_drag_car', 'drag_race_leave', 'couch_couch_beach',
#        'sit_crochet_play', 'play_play_down', 'play_play_lay',
#        'instrument_instrument_woman', 'kitten_food_kitten',
#        'tray_tray_on', 'at_street_across', 'dog_white_two',
#        'dog_white_breed', 'stare_street_look', 'white_dog_different',
#        'at_stare_at', 'color_color_stand', 'color_color_wear',
#        'color_color_in', 'talk_officer_to', 'fish_fish_follow',
#        'sit_sit_front', 'sit_sit_restaurant', 'sit_sit_in',
#        'sit_sit_relax', 'cry_cry_scream', 'empty_empty_carelessly',
#        'container_container_frog', 'empty_empty_hold', 'man_man_dim',
#        'man_man_people', 'bent_arm_green', 'young_boy_high',
#        'arm_knee_shirt', 'boy_young_person', 'sweater_pink_grassy',
#        'staircase_concrete_step', 'little_child_small',
#        'child_little_outdoors', 'sweater_pink_area', 'lie_read_over',
#        'read_lie_rock', 'player_football_crowd', 'football_player_game',
#        'family_child_man', 'child_family_kid', 'family_child_asian',
#        'child_family_three', 'pursue_turn_chase', 'dog_dog_yellow',
#        'karate_practice_costume', 'practice_practice_fight',
#        'practice_practice_in', 'man_three_boy', 'surround_stand_stone',
#        'child_school_man', 'surround_stand_beside', 'stand_stand_blue',
#        'stand_stand_in', 'stand_stand_jeans', 'lady_lady_house',
#        'stand_child_front', 'surround_stand_build', 'dog_white_tree',
#        'dog_white_on', 'white_dog_stump', 'white_dog_sit',
#        'miss_miss_knock', 'small_two_young', 'small_people_adult',
#        'two_people_five', 'small_two_young', 'small_people_adult',
#        'two_people_five', 'swimsuit_red_shorts', 'pool_kiddie_paddling',
#        'grass_grass_green', 'stand_stand_with', 'stand_stand_beak',
#        'stand_stand_yellow', 'purple_shirt_black', 'stand_chap_pose',
#        'chap_stand_camera', 'shirt_purple_wear', 'leather_chap_for',
#        'ginger_ginger_onion', 'cut_cut_slice', 'eat_corn_eat',
#        'ginger_ginger_onion', 'cut_cut_slice', 'small_dog_big',
#        'wear_wear_ride', 'long_sleeve_in', 'man_unicycle_checkered',
#        'run_run_wild', 'run_run_move', 'run_run_through',
#        'sing_dance_with', 'tongue_hat_colored', 'girl_two_kid',
#        'tongue_hat_blue', 'tongue_hat_green', 'cut_cut_hold',
#        'tomato_tomato_whole', 'man_man_woman', 'throw_go_with',
#        'down_up_dark', 'down_up_hair', 'blonde_boy_smile',
#        'boy_blonde_girl', 'blonde_boy_little', 'kid_kid_child',
#        'person_person_woman', 'child_small_father', 'child_two_girl',
#        'fountain_jump_front', 'behind_jump_in', 'climb_statue_on',
#        'climb_statue_play', 'small_child_two', 'cub_tiger_baby',
#        'ball_ball_doll', 'jacket_with_pants', 'with_jacket_through',
#        'red_with_state', 'jacket_with_khaki', 'person_person_man',
#        'red_with_european', 'with_hooded_in', 'dance_dance_pray',
#        'dance_dance_fervently', 'sticky_goo_pasta', 'out_pull_into',
#        'pull_out_put', 'pull_out_dish', 'stand_stand_run',
#        'biker_biker_man', 'wood_wood_wooded', 'wood_wood_area',
#        'kid_kid_child', 'person_person_athlete', 'jacket_pink_crowded',
#        'jacket_pink_stadium', 'person_person_four', 'person_person_woman',
#        'on_grass_in', 'play_on_rest', 'deny_deny_grant',
#        'instrument_instrument_topless', 'instrument_instrument_woman',
#        'instrument_instrument_young', 'mushroom_mushroom_elephant',
#        'person_person_woman', 'play_play_practice',
#        'street_crowded_almost', 'crowded_street_empty', 'play_play_lay',
#        'play_play_down', 'player_jersey_official', 'knife_tree_bike',
#        'at_dangerously_with', 'at_tree_against', 'man_man_dangerous',
#        'attentively_student_listen', 'attentively_student_at',
#        'student_attentively_class', 'look_attentively_front',
#        'classroom_of_uniform', 'stand_stand_wade', 'stand_stand_ocean',
#        'stand_stand_blue', 'stand_stand_through', 'pack_pack_sing',
#        'pack_pack_play', 'two_people_snowboard', 'two_people_jumper',
#        'two_people_practicing', 'sing_dance_in', 'sing_dance_rain',
#        'sit_sit_hat', 'sit_sit_with', 'sit_sit_backward'], dtype='<U40')

# %%
EMBEDDING_FILE = 'GoogleNews-vectors-negative300.bin'

# %%
stops = set(stopwords.words('english'))
vocabulary = dict()
inverse_vocabulary = ['<unk>'] 
sentences_cols = ['sentence1', 'sentence2', 'sim']
sentences_cols2 = ['sentence1', 'sentence2']

# Load training and test set
inputfile_sentences = []
for i, label in enumerate(load_target):
    f = open("plain/sick_"+load_sick_id[i]+".txt", "r")
    s = f.readlines()
    f.close()
    sim = load_source[i]
    target = label
    inputfile_sentences.append([s[0].strip(), s[1], sim, target])
df = pd.DataFrame(inputfile_sentences, columns=['sentence1', 'sentence2', 'sim', 'target'])
half = int(len(inputfile_sentences)/2)
train_df = df[:half]
test_df = df[half:]

def text_to_word_list(text):
    ''' Pre process and convert texts to a list of words '''
    text = str(text)
    text = text.lower()

    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)

    text = text.split()

    return text

#word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)
word2vec = word2vec_model.wv

# Iterate over the sentences only of both training and test datasets
for dataset in [train_df, test_df]:
    for index, row in dataset.iterrows():

        # Iterate through the text of both sentences of the row
        for sentence in sentences_cols:

            q2n = []  # q2n -> sentence numbers representation
            for word in text_to_word_list(row[sentence]):

                # Check for unwanted words
                if word in stops and word not in word2vec.vocab:
                    continue

                if word not in vocabulary:
                    vocabulary[word] = len(inverse_vocabulary)
                    q2n.append(len(inverse_vocabulary))
                    inverse_vocabulary.append(word)
                else:
                    q2n.append(vocabulary[word])

            # Replace sentence as word to sentence as number representation
            dataset.set_value(index, sentence, q2n)

# %%
embedding_dim = 50

embeddings = 1 * np.random.randn(len(vocabulary) + 1, embedding_dim)  # This will be the embedding matrix
#embeddings = 1 * np.random.randn(301, embedding_dim) #temporarily
embeddings[0] = 0  # So that the padding will be ignored

# %%
# Build the embedding matrix
for word, index in vocabulary.items():
    if word in word2vec.vocab:
        embeddings[index] = word2vec.word_vec(word)

del word2vec

# %%
max_seq_length = max(train_df.sentence1.map(lambda x: len(x)).max(),
                     train_df.sentence2.map(lambda x: len(x)).max(),
                     test_df.sentence1.map(lambda x: len(x)).max(),
                     test_df.sentence2.map(lambda x: len(x)).max())

# %%
# Split to train validation
validation_size = 2000
training_size = len(train_df) - validation_size

X = train_df[sentences_cols]
Y = train_df['sim']

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size)

# Split to dicts
X_train = {'left': X_train.sentence1, 'right': X_train.sentence2}
X_validation = {'left': X_validation.sentence1, 'right': X_validation.sentence2}
X_test = {'left': test_df.sentence1, 'right': test_df.sentence2}

# Convert labels to their numpy representations
Y_train = Y_train.values
Y_validation = Y_validation.values

# Zero padding
for dataset, side in itertools.product([X_train, X_validation], ['left', 'right']):
    dataset[side] = pad_sequences(dataset[side], maxlen=max_seq_length)

# Make sure everything is ok
assert X_train['left'].shape == X_train['right'].shape
assert len(X_train['left']) == len(Y_train)

# %%
# Model variables
n_hidden = 50
gradient_clipping_norm = 1.25
batch_size = 64
n_epoch = 25
max_seq_length = 100 #temporarily

def exponent_neg_manhattan_distance(left, right):
    ''' Helper function for the similarity estimate of the LSTMs outputs'''
    return K.exp(-K.sum(K.abs(left-right), axis=1, keepdims=True))*5

# The visible layer
left_input = Input(shape=(max_seq_length,), dtype='int32')
right_input = Input(shape=(max_seq_length,), dtype='int32')

embedding_layer = Embedding(len(embeddings), embedding_dim, weights=[embeddings], input_length=max_seq_length, trainable=False)

# Embedded version of the inputs
encoded_left = embedding_layer(left_input)
encoded_right = embedding_layer(right_input)

# Since this is a siamese network, both sides share the same LSTM
shared_lstm = Bidirectional(LSTM(n_hidden))

left_output = shared_lstm(encoded_left)
right_output = shared_lstm(encoded_right)

th_output = Concatenate()([left_output, right_output])

sim_input = Input(shape=(28,))
sim_input1 = Dense(100, activation='relu')(sim_input)
sim_input2 = Dense(28, activation='relu')(sim_input1)
merge_input = Concatenate()([th_output, sim_input2])

predictions = Dense(1, init='uniform', activation='sigmoid')(merge_input)
model = Model([left_input, right_input, sim_input], outputs=predictions)

#base_model = Sequential()
#base_model.add(Dense(input_dim=14, units=1))
#base_model.add(Dense(out_dim, input_dim=14, init='uniform', activation=activation))
#base_model.add(Dense(14, init='uniform', activation=activation))
#base_model.add(Dense(1, init='uniform', activation='sigmoid'))

# Calculates the distance as defined by the MaLSTM model
#malstm_distance = Merge(mode=lambda x: exponent_neg_manhattan_distance(x[0], x[1]), output_shape=lambda x: (x[0][0], 1))([left_output, right_output])

# Pack it all up into a model
#malstm = Model([left_input, right_input], [malstm_distance])

# Adadelta optimizer, with gradient clipping by norm
optimizer = Adadelta(clipnorm=gradient_clipping_norm)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#malstm.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /Users/yanakahitomi/.pyenv/versions/ccg2lambda/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1044: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# /Users/yanakahitomi/.pyenv/versions/ccg2lambda/lib/python3.5/site-packages/ipykernel/__main__.py:35: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
# WARNING:tensorflow:From /Users/yanakahitomi/.pyenv/versions/ccg2lambda/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
# Start training
training_start_time = time()

malstm_trained = malstm.fit([X_train['left'], X_train['right']], Y_train, batch_size=batch_size, nb_epoch=n_epoch,
                            validation_data=([X_validation['left'], X_validation['right']], Y_validation))

print("Training time finished.\n{} epochs in {}".format(n_epoch, datetime.timedelta(seconds=time()-training_start_time)))
# Out:
# /Users/yanakahitomi/.pyenv/versions/3.5.0/envs/ccg2lambda/lib/python3.5/site-packages/ipykernel/__main__.py:28: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /Users/yanakahitomi/.pyenv/versions/3.5.0/envs/ccg2lambda/lib/python3.5/site-packages/ipykernel/__main__.py:42: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 2963 samples, validate on 2000 samples
# Epoch 1/25
# 2963/2963 [==============================] - 4s - loss: 5.0168 - acc: 0.0213 - val_loss: 3.6046 - val_acc: 0.0465
# Epoch 2/25
# 2963/2963 [==============================] - 2s - loss: 2.6120 - acc: 0.0493 - val_loss: 1.7296 - val_acc: 0.0420
# Epoch 3/25
# 2963/2963 [==============================] - 2s - loss: 1.2918 - acc: 0.0385 - val_loss: 1.0884 - val_acc: 0.0410
# Epoch 4/25
# 2963/2963 [==============================] - 2s - loss: 0.8520 - acc: 0.0469 - val_loss: 0.8699 - val_acc: 0.0455
# Epoch 5/25
# 2963/2963 [==============================] - 2s - loss: 0.6671 - acc: 0.0499 - val_loss: 0.7730 - val_acc: 0.0480
# Epoch 6/25
# 2963/2963 [==============================] - 2s - loss: 0.5611 - acc: 0.0547 - val_loss: 0.7083 - val_acc: 0.0490
# Epoch 7/25
# 2963/2963 [==============================] - 2s - loss: 0.4847 - acc: 0.0611 - val_loss: 0.6720 - val_acc: 0.0510
# Epoch 8/25
# 2963/2963 [==============================] - 2s - loss: 0.4275 - acc: 0.0618 - val_loss: 0.6302 - val_acc: 0.0510
# Epoch 9/25
# 2963/2963 [==============================] - 2s - loss: 0.3784 - acc: 0.0675 - val_loss: 0.6041 - val_acc: 0.0535
# Epoch 10/25
# 2963/2963 [==============================] - 2s - loss: 0.3426 - acc: 0.0682 - val_loss: 0.5813 - val_acc: 0.0545
# Epoch 11/25
# 2963/2963 [==============================] - 2s - loss: 0.3127 - acc: 0.0742 - val_loss: 0.5667 - val_acc: 0.0545
# Epoch 12/25
# 2963/2963 [==============================] - 2s - loss: 0.2879 - acc: 0.0749 - val_loss: 0.5457 - val_acc: 0.0545
# Epoch 13/25
# 2963/2963 [==============================] - 2s - loss: 0.2674 - acc: 0.0756 - val_loss: 0.5401 - val_acc: 0.0555
# Epoch 14/25
# 2963/2963 [==============================] - 2s - loss: 0.2517 - acc: 0.0776 - val_loss: 0.5266 - val_acc: 0.0570
# Epoch 15/25
# 2963/2963 [==============================] - 2s - loss: 0.2366 - acc: 0.0783 - val_loss: 0.5192 - val_acc: 0.0575
# Epoch 16/25
# 2963/2963 [==============================] - 2s - loss: 0.2258 - acc: 0.0803 - val_loss: 0.5175 - val_acc: 0.0575
# Epoch 17/25
# 2963/2963 [==============================] - 2s - loss: 0.2152 - acc: 0.0800 - val_loss: 0.5078 - val_acc: 0.0570
# Epoch 18/25
# 2963/2963 [==============================] - 2s - loss: 0.2050 - acc: 0.0840 - val_loss: 0.5046 - val_acc: 0.0580
# Epoch 19/25
# 2963/2963 [==============================] - 2s - loss: 0.1980 - acc: 0.0823 - val_loss: 0.5204 - val_acc: 0.0580
# Epoch 20/25
# 2963/2963 [==============================] - 2s - loss: 0.1912 - acc: 0.0864 - val_loss: 0.5003 - val_acc: 0.0590
# Epoch 21/25
# 2963/2963 [==============================] - 2s - loss: 0.1864 - acc: 0.0844 - val_loss: 0.4949 - val_acc: 0.0600
# Epoch 22/25
# 2963/2963 [==============================] - 2s - loss: 0.1802 - acc: 0.0867 - val_loss: 0.4941 - val_acc: 0.0600
# Epoch 23/25
# 2963/2963 [==============================] - 2s - loss: 0.1754 - acc: 0.0891 - val_loss: 0.5026 - val_acc: 0.0615
# Epoch 24/25
# 2963/2963 [==============================] - 2s - loss: 0.1711 - acc: 0.0888 - val_loss: 0.4922 - val_acc: 0.0610
# Epoch 25/25
# 2963/2963 [==============================] - 2s - loss: 0.1656 - acc: 0.0908 - val_loss: 0.4878 - val_acc: 0.0615
# Training time finished.
# 25 epochs in 0:01:08.450730

# %%
# Plot accuracy
plt.plot(malstm_trained.history['acc'])
plt.plot(malstm_trained.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot loss
plt.plot(malstm_trained.history['loss'])
plt.plot(malstm_trained.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
import gensim.downloader as api

info = api.info()  # show info about available models/datasets
word2vec_model = api.load("glove-wiki-gigaword-50")  # download the model and return as object ready for use
